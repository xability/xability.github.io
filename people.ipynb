# %% [raw]
# ---
# title: "People"
# author: "xAbility Design Lab"
# format: html
# ---

# %% [markdown]
# # People
#
# ## Principal Investigator
#
# <div class="people-section">
#   <div class="people-cards">
#     <div class="card">
#       <div class="card-header">
#         <img src="image.png" class="avatar-img" alt="Dr. JooYoung Seo profile picture"/>
#         <div>
#           <h3 class="card-title">Dr. JooYoung Seo</h3>
#           <p class="card-subtitle">Assistant Professor of Information Sciences</p>
#           <a href="mailto:jseo1005\@illinois.edu" class="card-email">jseo1005\@illinois.edu</a>
#         </div>
#       </div>
#       <div class="card-content">
#         <p class="card-bio">Dr. JooYoung Seo leads the (x)Ability Design Lab, focusing on accessibility research. He is an assistant professor in the School of Information Sciences and a faculty affiliate in various departments at the University of Illinois Urbana-Champaign. His research involves accessible computing, universal design, inclusive data science, and equitable healthcare technologies.</p>
#       </div>
#     </div>
#   </div>
# </div>
#
# ## PhD Students
#
# <div class="people-section">
#   <div class="people-cards">
#     <div class="card">
#       <div class="card-header">
#         <div class="avatar">Sa</div>
#         <div>
#           <h3 class="card-title">Sanchita Kamath</h3>
#           <p class="card-subtitle">PhD Student</p>
#           <a href="mailto:ssk11\@illinois.edu" class="card-email">ssk11\@illinois.edu</a>
#         </div>
#       </div>
#       <div class="card-content">
#         <p class="card-bio">Sanchita is a Ph.D. student in Information Sciences, specializing in Human-Computer Interaction. Her research focuses on designing and developing immersive, user-centered solutions that enhance accessibility and inclusivity, particularly for blind and low-vision (BLV) individuals.</p>
#       </div>
#     </div>
#
#     <div class="card">
#       <div class="card-header">
#         <div class="avatar">Az</div>
#         <div>
#           <h3 class="card-title">Aziz Zeidieh</h3>
#           <p class="card-subtitle">PhD Student</p>
#           <a href="mailto:azeidi2@illinois.edu" class="card-email">azeidi2@illinois.edu</a>
#         </div>
#       </div>
#       <div class="card-content">
#         <p class="card-bio">Aziz is a PhD student in Informatics. His research explores the intersection of accessibility, security, privacy, and usability. He focuses on authentication methods for low vision or blind individuals and works on projects involving multimodal data representation, misinformation, and extended reality (XR) in sports.</p>
#       </div>
#     </div>
#   </div>
# </div>
#
# ## Research Assistants
#
# <div class="people-section">
#   <div class="people-cards">
#     <p>No Research Assistants currently listed.</p>
#   </div>
# </div>
#
# ```{css, echo=FALSE}
# .people-section {
#   margin-bottom: 3rem;
# }
# .section-title {
#   font-size: 1.5rem;
#   font-weight: bold;
#   margin-bottom: 1rem;
#   color: #2d3748;
# }
# .people-cards {
#   display: flex;
#   flex-wrap: wrap;
#   justify-content: flex-start;
#   gap: 2rem;
# }
# .card {
#   width: 100%;
#   max-width: 400px;
#   border: 1px solid #e2e8f0;
#   border-radius: 0.5rem;
#   overflow: hidden;
#   box-shadow: 0 4px 6px -1px rgba(0, 0, 0, 0.1), 0 2px 4px -1px rgba(0, 0, 0, 0.06);
# }
# .card-header {
#   display: flex;
#   align-items: center;
#   padding: 1rem;
#   background-color: #f7fafc;
# }
# .avatar {
#   width: 80px;
#   height: 80px;
#   border-radius: 50%;
#   background-color: #cbd5e0;
#   display: flex;
#   align-items: center;
#   justify-content: center;
#   font-size: 1.5rem;
#   font-weight: bold;
#   color: #4a5568;
#   margin-right: 1rem;
# }
# .avatar-img {
#   width: 80px;
#   height: 80px;
#   border-radius: 50%;
#   margin-right: 1rem;
# }
# .card-title {
#   margin: 0;
#   font-size: 1.25rem;
#   font-weight: bold;
#   color: #2d3748;
# }
# .card-subtitle {
#   margin: 0.25rem 0;
#   font-size: 0.875rem;
#   color: #718096;
# }
# .card-email {
#   font-size: 0.875rem;
#   color: #4299e1;
#   text-decoration: none;
# }
# .card-email:hover {
#   text-decoration: underline;
# }
# .card-content {
#   padding: 1rem;
# }
# .card-bio {
#   margin: 0;
#   font-size: 0.875rem;
#   color: #4a5568;
#   line-height: 1.5;
# }
